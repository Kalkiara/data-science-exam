# %%
# load packages

import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
# load data

df = pd.read_csv("/work/MiaJacobsen#3200/data-science-exam/data/top_songs_by_month.csv")

# %%
# inspect
print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (21790, 23)
# Unnamed: 0.1                 int64
# Unnamed: 0                 float64
# danceability               float64
# energy                     float64
# key                          int64
# loudness                   float64
# mode                         int64
# speechiness                float64
# acousticness               float64
# instrumentalness           float64
# liveness                   float64
# valence                    float64
# tempo                      float64
# type                        object
# id                          object
# uri                         object
# track_href                  object
# analysis_url                object
# duration_ms                  int64
# time_signature               int64
# song_name                   object
# scraped_url                 object
# date                datetime64[ns]
# dtype: object
#    Unnamed: 0.1  Unnamed: 0  danceability  energy  key  loudness  mode  \
# ...

# %%
# making date datetime
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# Unnamed: 0.1                 int64
# Unnamed: 0                 float64
# danceability               float64
# energy                     float64
# key                          int64
# loudness                   float64
# mode                         int64
# speechiness                float64
# acousticness               float64
# instrumentalness           float64
# liveness                   float64
# valence                    float64
# tempo                      float64
# type                        object
# id                          object
# uri                         object
# track_href                  object
# analysis_url                object
# duration_ms                  int64
# time_signature               int64
# song_name                   object
# scraped_url                 object
# date                datetime64[ns]
# dtype: object

# %%
# looking at a subset of the data
df1 = df.iloc[0:2000, :]
df1 = df1[['date', 'danceability']]

# %%
# trying to smooth the line (medium success)
df1['mov_avg'] = df1['danceability'].rolling(365*3).mean()

# %%
# exploratory plotting
sns.lineplot(data = df1, x = "date", y = "mov_avg")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ideas for plotting:
# - doing above plot but for 20 year periods (i.e., 1960-1980, 1980-2000, 2000-2020) and compare
# - area plot of different features (so layer them on top of eachother over time) (requires some standardization)
# - idk make above pretty somehow?
